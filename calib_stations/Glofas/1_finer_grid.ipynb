# %%
import numpy as np
import pandas as pd
import rioxarray
import pyflwdir
from tqdm.auto import tqdm
from pathlib import Path

import warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s | %(levelname)s | %(message)s')
logger = logging.getLogger(__name__)

from lisfloodpreprocessing import Config
from lisfloodpreprocessing.utils import find_pixel, catchment_polygon

# %%
# CONFIGURATION

cfg = Config('Z:/nahaUsers/casadje/datasets/reservoirs/ResOpsES/ancillary/lfcoordinates/config.yml')

# %%
# READ INPUT DATA

# read upstream map with fine resolution
upstream_fine = rioxarray.open_rasterio(cfg.UPSTREAM_FINE).squeeze(dim='band')
logger.info(f'Map of upstream area corretly read: {cfg.UPSTREAM_FINE}')

# read local drainage direction map
ldd_fine = rioxarray.open_rasterio(cfg.LDD_FINE).squeeze(dim='band')
logger.info(f'Map of local drainage directions corretly read: {cfg.LDD_FINE}')

# resolution of the input map
cellsize = np.mean(np.diff(upstream_fine.x)) # degrees
cellsize_arcsec = int(np.round(cellsize * 3600, 0)) # arcsec
suffix_fine = f'{cellsize_arcsec}sec'
logger.info(f'The resolution of the finer grid is {cellsize_arcsec} arcseconds')

# read stations text file
stations = pd.read_csv(cfg.STATIONS, index_col='ID')
stations = stations[stations.area >= cfg.MIN_AREA]
logger.info(f'Table of stations correctly read: {cfg.STATIONS}')
# Out:
# 2024-08-21 11:26:26,526 | INFO | Map of upstream area corretly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\MERIT\upa.tif
# 2024-08-21 11:26:26,530 | INFO | Map of local drainage directions corretly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\MERIT\dir.tif
# 2024-08-21 11:26:26,530 | INFO | The resolution of the finer grid is 3 arcseconds
# 2024-08-21 11:26:26,546 | INFO | Table of stations correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\grand.csv

# %%
# PROCESSING

# add columns to the table of stations
new_cols = sorted([f'{col}_{suffix_fine}' for col in stations.columns])
stations[new_cols] = np.nan

# create river network
fdir_fine = pyflwdir.from_array(ldd_fine.data,
                                ftype='d8', 
                                transform=ldd_fine.rio.transform(),
                                check_ftype=False,
                                latlon=True)

# output path
SHAPE_FOLDER_FINE = cfg.SHAPE_FOLDER / suffix_fine
SHAPE_FOLDER_FINE.mkdir(parents=True, exist_ok=True)

for ID, attrs in tqdm(stations.iterrows(), total=stations.shape[0], desc='stations'):  

    # reference coordinates and upstream area
    lat_ref, lon_ref, area_ref = attrs[['lat', 'lon', 'area']]

    # search new coordinates in an increasing range
    ranges = [55, 101, 151]
    penalties = [500, 500, 1000]
    factors = [2, .5, .25]
    acceptable_errors = [50, 80, np.nan]
    for rangexy, penalty, factor, max_error in zip(ranges, penalties, factors, acceptable_errors):
        logger.info(f'Set range to {rangexy}')
        lat, lon, error = find_pixel(upstream_fine, lat_ref, lon_ref, area_ref, rangexy=rangexy, penalty=penalty, factor=factor)
        if error <= max_error:
            break

    # update new columns in 'stations'
    stations.loc[ID, new_cols] = [int(upstream_fine.sel(y=lat, x=lon).item()), round(lat, 6), round(lon, 6)]
    
    # boolean map of the catchment associated to the corrected coordinates
    basin_arr = fdir_fine.basins(xy=(lon, lat)).astype(np.int32)

    # vectorize the boolean map into geopandas
    basin_gdf = catchment_polygon(basin_arr.astype(np.int32),
                                  transform=ldd_fine.rio.transform(),
                                  crs=ldd_fine.rio.crs,
                                  name='ID')
    basin_gdf['ID'] = ID
    basin_gdf.set_index('ID', inplace=True)
    basin_gdf[attrs.index] = attrs.values

    # export shape file
    output_file = SHAPE_FOLDER_FINE / f'{ID}.shp'
    basin_gdf.to_file(output_file)
    logger.info(f'\nCatchment {ID} exported as shapefile: {output_file}')

# export results
stations.sort_index(axis=1, inplace=True)
output_csv = cfg.STATIONS.parent / f'{cfg.STATIONS.stem}_{suffix_fine}.csv'
stations.to_csv(output_csv)
logger.info(f'Coordinates an upstream area in the finer grid have been exported to: {output_csv}')
# Out:
# stations:   0%|          | 0/253 [00:00<?, ?it/s]
# 2024-08-21 11:26:41,905 | INFO | Set range to 55
# 2024-08-21 11:26:50,389 | INFO |
# Catchment 2648 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2648.shp
# 2024-08-21 11:26:50,405 | INFO | Set range to 55
# 2024-08-21 11:26:54,510 | INFO |
# Catchment 2649 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2649.shp
# 2024-08-21 11:26:54,510 | INFO | Set range to 55
# 2024-08-21 11:26:58,287 | INFO |
# Catchment 2650 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2650.shp
# 2024-08-21 11:26:58,287 | INFO | Set range to 55
# 2024-08-21 11:27:01,960 | INFO |
# Catchment 2651 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2651.shp
# 2024-08-21 11:27:01,960 | INFO | Set range to 55
# 2024-08-21 11:27:05,690 | INFO |
# Catchment 2652 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2652.shp
# 2024-08-21 11:27:05,690 | INFO | Set range to 55
# 2024-08-21 11:27:09,370 | INFO |
# Catchment 2653 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2653.shp
# 2024-08-21 11:27:09,385 | INFO | Set range to 55
# 2024-08-21 11:27:13,045 | INFO |
# Catchment 2654 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2654.shp
# 2024-08-21 11:27:13,045 | INFO | Set range to 55
# 2024-08-21 11:27:16,744 | INFO |
# Catchment 2656 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2656.shp
# 2024-08-21 11:27:16,754 | INFO | Set range to 55
# 2024-08-21 11:27:20,561 | INFO |
# Catchment 2657 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2657.shp
# 2024-08-21 11:27:20,563 | INFO | Set range to 55
# 2024-08-21 11:27:24,147 | INFO |
# Catchment 2658 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2658.shp
# 2024-08-21 11:27:24,157 | INFO | Set range to 55
# 2024-08-21 11:27:28,002 | INFO |
# Catchment 2660 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2660.shp
# 2024-08-21 11:27:28,002 | INFO | Set range to 55
# 2024-08-21 11:27:31,622 | INFO |
# Catchment 2661 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2661.shp
# 2024-08-21 11:27:31,622 | INFO | Set range to 55
# 2024-08-21 11:27:35,216 | INFO |
# Catchment 2662 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2662.shp
# 2024-08-21 11:27:35,218 | INFO | Set range to 55
# 2024-08-21 11:27:38,876 | INFO |
# Catchment 2663 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2663.shp
# 2024-08-21 11:27:38,876 | INFO | Set range to 55
# 2024-08-21 11:27:42,561 | INFO |
# Catchment 2664 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2664.shp
# 2024-08-21 11:27:42,561 | INFO | Set range to 55
# 2024-08-21 11:27:46,693 | INFO |
# Catchment 2665 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2665.shp
# 2024-08-21 11:27:46,693 | INFO | Set range to 55
# 2024-08-21 11:27:50,330 | INFO |
# Catchment 2666 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2666.shp
# 2024-08-21 11:27:50,330 | INFO | Set range to 55
# 2024-08-21 11:27:54,133 | INFO |
# Catchment 2667 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2667.shp
# 2024-08-21 11:27:54,133 | INFO | Set range to 55
# 2024-08-21 11:27:57,989 | INFO |
# Catchment 2668 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2668.shp
# 2024-08-21 11:27:57,997 | INFO | Set range to 55
# 2024-08-21 11:28:01,672 | INFO |
# Catchment 2669 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2669.shp
# 2024-08-21 11:28:01,687 | INFO | Set range to 55
# 2024-08-21 11:28:05,435 | INFO |
# Catchment 2670 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2670.shp
# 2024-08-21 11:28:05,435 | INFO | Set range to 55
# 2024-08-21 11:28:09,123 | INFO |
# Catchment 2671 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2671.shp
# 2024-08-21 11:28:09,123 | INFO | Set range to 55
# 2024-08-21 11:28:12,771 | INFO |
# Catchment 2672 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2672.shp
# 2024-08-21 11:28:12,787 | INFO | Set range to 55
# 2024-08-21 11:28:16,413 | INFO |
# Catchment 2673 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2673.shp
# 2024-08-21 11:28:16,413 | INFO | Set range to 55
# 2024-08-21 11:28:20,053 | INFO |
# Catchment 2674 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2674.shp
# 2024-08-21 11:28:20,053 | INFO | Set range to 55
# 2024-08-21 11:28:23,738 | INFO |
# Catchment 2675 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2675.shp
# 2024-08-21 11:28:23,738 | INFO | Set range to 55
# 2024-08-21 11:28:27,453 | INFO |
# Catchment 2676 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2676.shp
# 2024-08-21 11:28:27,453 | INFO | Set range to 55
# 2024-08-21 11:28:31,117 | INFO |
# Catchment 2677 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2677.shp
# 2024-08-21 11:28:31,117 | INFO | Set range to 55
# 2024-08-21 11:28:34,737 | INFO |
# Catchment 2678 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2678.shp
# 2024-08-21 11:28:34,737 | INFO | Set range to 55
# 2024-08-21 11:28:38,412 | INFO |
# Catchment 2679 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2679.shp
# 2024-08-21 11:28:38,427 | INFO | Set range to 55
# 2024-08-21 11:28:42,180 | INFO |
# Catchment 2680 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2680.shp
# 2024-08-21 11:28:42,180 | INFO | Set range to 55
# 2024-08-21 11:28:45,882 | INFO |
# Catchment 2681 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2681.shp
# 2024-08-21 11:28:45,882 | INFO | Set range to 55
# 2024-08-21 11:28:49,567 | INFO |
# Catchment 2682 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2682.shp
# 2024-08-21 11:28:49,567 | INFO | Set range to 55
# 2024-08-21 11:28:53,358 | INFO |
# Catchment 2683 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2683.shp
# 2024-08-21 11:28:53,358 | INFO | Set range to 55
# 2024-08-21 11:28:57,028 | INFO |
# Catchment 2684 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2684.shp
# 2024-08-21 11:28:57,028 | INFO | Set range to 55
# 2024-08-21 11:29:00,710 | INFO |
# Catchment 2685 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2685.shp
# 2024-08-21 11:29:00,710 | INFO | Set range to 55
# 2024-08-21 11:29:04,481 | INFO |
# Catchment 2686 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2686.shp
# 2024-08-21 11:29:04,481 | INFO | Set range to 55
# 2024-08-21 11:29:08,170 | INFO |
# Catchment 2687 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2687.shp
# 2024-08-21 11:29:08,170 | INFO | Set range to 55
# 2024-08-21 11:29:11,822 | INFO |
# Catchment 2688 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2688.shp
# 2024-08-21 11:29:11,822 | INFO | Set range to 55
# 2024-08-21 11:29:15,513 | INFO |
# Catchment 2689 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2689.shp
# 2024-08-21 11:29:15,513 | INFO | Set range to 55
# 2024-08-21 11:29:19,198 | INFO |
# Catchment 2690 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2690.shp
# 2024-08-21 11:29:19,198 | INFO | Set range to 55
# 2024-08-21 11:29:22,852 | INFO |
# Catchment 2691 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2691.shp
# 2024-08-21 11:29:22,852 | INFO | Set range to 55
# 2024-08-21 11:29:26,521 | INFO |
# Catchment 2692 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2692.shp
# 2024-08-21 11:29:26,521 | INFO | Set range to 55
# 2024-08-21 11:29:30,194 | INFO |
# Catchment 2693 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2693.shp
# 2024-08-21 11:29:30,196 | INFO | Set range to 55
# 2024-08-21 11:29:33,865 | INFO |
# Catchment 2694 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2694.shp
# 2024-08-21 11:29:33,865 | INFO | Set range to 55
# 2024-08-21 11:29:37,936 | INFO |
# Catchment 2695 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2695.shp
# 2024-08-21 11:29:37,936 | INFO | Set range to 55
# 2024-08-21 11:29:41,591 | INFO |
# Catchment 2696 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2696.shp
# 2024-08-21 11:29:41,591 | INFO | Set range to 55
# 2024-08-21 11:29:45,238 | INFO |
# Catchment 2697 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2697.shp
# 2024-08-21 11:29:45,238 | INFO | Set range to 55
# 2024-08-21 11:29:48,958 | INFO |
# Catchment 2699 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2699.shp
# 2024-08-21 11:29:48,958 | INFO | Set range to 55
# 2024-08-21 11:29:52,613 | INFO |
# Catchment 2700 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2700.shp
# 2024-08-21 11:29:52,613 | INFO | Set range to 55
# 2024-08-21 11:29:56,265 | INFO |
# Catchment 2701 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2701.shp
# 2024-08-21 11:29:56,274 | INFO | Set range to 55
# 2024-08-21 11:29:59,912 | INFO |
# Catchment 2702 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2702.shp
# 2024-08-21 11:29:59,912 | INFO | Set range to 55
# 2024-08-21 11:30:03,598 | INFO |
# Catchment 2703 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2703.shp
# 2024-08-21 11:30:03,598 | INFO | Set range to 55
# 2024-08-21 11:30:07,196 | INFO |
# Catchment 2704 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2704.shp
# 2024-08-21 11:30:07,196 | INFO | Set range to 55
# 2024-08-21 11:30:10,949 | INFO |
# Catchment 2706 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2706.shp
# 2024-08-21 11:30:10,949 | INFO | Set range to 55
# 2024-08-21 11:30:14,695 | INFO |
# Catchment 2707 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2707.shp
# 2024-08-21 11:30:14,695 | INFO | Set range to 55
# 2024-08-21 11:30:18,297 | INFO |
# Catchment 2708 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2708.shp
# 2024-08-21 11:30:18,297 | INFO | Set range to 55
# 2024-08-21 11:30:21,944 | INFO |
# Catchment 2709 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2709.shp
# 2024-08-21 11:30:21,944 | INFO | Set range to 55
# 2024-08-21 11:30:25,610 | INFO |
# Catchment 2710 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\
exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2867.shp
# 2024-08-21 11:37:10,405 | INFO | Set range to 55
# 2024-08-21 11:37:14,046 | INFO |
# Catchment 2868 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2868.shp
# 2024-08-21 11:37:14,046 | INFO | Set range to 55
# 2024-08-21 11:37:17,704 | INFO |
# Catchment 2869 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2869.shp
# 2024-08-21 11:37:17,704 | INFO | Set range to 55
# 2024-08-21 11:37:21,342 | INFO |
# Catchment 2870 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2870.shp
# 2024-08-21 11:37:21,358 | INFO | Set range to 55
# 2024-08-21 11:37:25,006 | INFO |
# Catchment 2871 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2871.shp
# 2024-08-21 11:37:25,006 | INFO | Set range to 55
# 2024-08-21 11:37:28,670 | INFO |
# Catchment 2872 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2872.shp
# 2024-08-21 11:37:28,686 | INFO | Set range to 55
# 2024-08-21 11:37:32,374 | INFO |
# Catchment 2873 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2873.shp
# 2024-08-21 11:37:32,374 | INFO | Set range to 55
# 2024-08-21 11:37:36,056 | INFO |
# Catchment 2875 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2875.shp
# 2024-08-21 11:37:36,056 | INFO | Set range to 55
# 2024-08-21 11:37:39,686 | INFO |
# Catchment 2876 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2876.shp
# 2024-08-21 11:37:39,686 | INFO | Set range to 55
# 2024-08-21 11:37:43,420 | INFO |
# Catchment 2878 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2878.shp
# 2024-08-21 11:37:43,420 | INFO | Set range to 55
# 2024-08-21 11:37:47,561 | INFO |
# Catchment 2879 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2879.shp
# 2024-08-21 11:37:47,577 | INFO | Set range to 55
# 2024-08-21 11:37:51,202 | INFO |
# Catchment 2880 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2880.shp
# 2024-08-21 11:37:51,202 | INFO | Set range to 55
# 2024-08-21 11:37:54,796 | INFO |
# Catchment 2882 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2882.shp
# 2024-08-21 11:37:54,796 | INFO | Set range to 55
# 2024-08-21 11:37:58,603 | INFO |
# Catchment 2883 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2883.shp
# 2024-08-21 11:37:58,606 | INFO | Set range to 55
# 2024-08-21 11:38:02,327 | INFO |
# Catchment 2884 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2884.shp
# 2024-08-21 11:38:02,327 | INFO | Set range to 55
# 2024-08-21 11:38:05,998 | INFO |
# Catchment 2885 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2885.shp
# 2024-08-21 11:38:05,998 | INFO | Set range to 55
# 2024-08-21 11:38:10,108 | INFO |
# Catchment 2886 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2886.shp
# 2024-08-21 11:38:10,124 | INFO | Set range to 55
# 2024-08-21 11:38:13,733 | INFO |
# Catchment 2887 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2887.shp
# 2024-08-21 11:38:13,733 | INFO | Set range to 55
# 2024-08-21 11:38:17,374 | INFO |
# Catchment 2888 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2888.shp
# 2024-08-21 11:38:17,374 | INFO | Set range to 55
# 2024-08-21 11:38:21,034 | INFO |
# Catchment 2889 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2889.shp
# 2024-08-21 11:38:21,034 | INFO | Set range to 55
# 2024-08-21 11:38:24,655 | INFO |
# Catchment 2891 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2891.shp
# 2024-08-21 11:38:24,670 | INFO | Set range to 55
# 2024-08-21 11:38:28,280 | INFO |
# Catchment 2892 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2892.shp
# 2024-08-21 11:38:28,280 | INFO | Set range to 55
# 2024-08-21 11:38:31,967 | INFO |
# Catchment 2893 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2893.shp
# 2024-08-21 11:38:31,967 | INFO | Set range to 55
# 2024-08-21 11:38:35,623 | INFO |
# Catchment 2894 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2894.shp
# 2024-08-21 11:38:35,623 | INFO | Set range to 55
# 2024-08-21 11:38:39,342 | INFO |
# Catchment 2895 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2895.shp
# 2024-08-21 11:38:39,342 | INFO | Set range to 55
# 2024-08-21 11:38:43,014 | INFO |
# Catchment 2896 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2896.shp
# 2024-08-21 11:38:43,014 | INFO | Set range to 55
# 2024-08-21 11:38:46,686 | INFO |
# Catchment 2897 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2897.shp
# 2024-08-21 11:38:46,686 | INFO | Set range to 55
# 2024-08-21 11:38:50,498 | INFO |
# Catchment 2899 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2899.shp
# 2024-08-21 11:38:50,498 | INFO | Set range to 55
# 2024-08-21 11:38:54,499 | INFO |
# Catchment 2900 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2900.shp
# 2024-08-21 11:38:54,499 | INFO | Set range to 55
# 2024-08-21 11:38:58,217 | INFO |
# Catchment 2901 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2901.shp
# 2024-08-21 11:38:58,217 | INFO | Set range to 55
# 2024-08-21 11:39:01,936 | INFO |
# Catchment 2902 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2902.shp
# 2024-08-21 11:39:01,936 | INFO | Set range to 55
# 2024-08-21 11:39:05,675 | INFO |
# Catchment 2904 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2904.shp
# 2024-08-21 11:39:05,677 | INFO | Set range to 55
# 2024-08-21 11:39:09,412 | INFO |
# Catchment 2908 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2908.shp
# 2024-08-21 11:39:09,412 | INFO | Set range to 55
# 2024-08-21 11:39:13,091 | INFO |
# Catchment 2909 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2909.shp
# 2024-08-21 11:39:13,091 | INFO | Set range to 55
# 2024-08-21 11:39:17,304 | INFO |
# Catchment 2910 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2910.shp
# 2024-08-21 11:39:17,304 | INFO | Set range to 55
# 2024-08-21 11:39:20,979 | INFO |
# Catchment 2911 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2911.shp
# 2024-08-21 11:39:20,979 | INFO | Set range to 55
# 2024-08-21 11:39:24,628 | INFO |
# Catchment 2912 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2912.shp
# 2024-08-21 11:39:24,628 | INFO | Set range to 55
# 2024-08-21 11:39:28,350 | INFO |
# Catchment 2913 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2913.shp
# 2024-08-21 11:39:28,350 | INFO | Set range to 55
# 2024-08-21 11:39:32,054 | INFO |
# Catchment 2914 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2914.shp
# 2024-08-21 11:39:32,054 | INFO | Set range to 55
# 2024-08-21 11:39:35,703 | INFO |
# Catchment 2915 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2915.shp
# 2024-08-21 11:39:35,703 | INFO | Set range to 55
# 2024-08-21 11:39:39,378 | INFO |
# Catchment 2916 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2916.shp
# 2024-08-21 11:39:39,378 | INFO | Set range to 55
# 2024-08-21 11:39:43,082 | INFO |
# Catchment 2917 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2917.shp
# 2024-08-21 11:39:43,092 | INFO | Set range to 55
# 2024-08-21 11:39:46,735 | INFO |
# Catchment 2918 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2918.shp
# 2024-08-21 11:39:46,735 | INFO | Set range to 55
# 2024-08-21 11:39:50,431 | INFO |
# Catchment 2919 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2919.shp
# 2024-08-21 11:39:50,433 | INFO | Set range to 55
# 2024-08-21 11:39:54,155 | INFO |
# Catchment 2920 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2920.shp
# 2024-08-21 11:39:54,155 | INFO | Set range to 55
# 2024-08-21 11:39:57,915 | INFO |
# Catchment 2921 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2921.shp
# 2024-08-21 11:39:57,915 | INFO | Set range to 55
# 2024-08-21 11:40:01,530 | INFO |
# Catchment 2922 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2922.shp
# 2024-08-21 11:40:01,530 | INFO | Set range to 55
# 2024-08-21 11:40:05,284 | INFO |
# Catchment 2923 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2923.shp
# 2024-08-21 11:40:05,285 | INFO | Set range to 55
# 2024-08-21 11:40:09,061 | INFO |
# Catchment 2924 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2924.shp
# 2024-08-21 11:40:09,061 | INFO | Set range to 55
# 2024-08-21 11:40:12,852 | INFO |
# Catchment 2925 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2925.shp
# 2024-08-21 11:40:12,852 | INFO | Set range to 55
# 2024-08-21 11:40:16,577 | INFO |
# Catchment 2926 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2926.shp
# 2024-08-21 11:40:16,577 | INFO | Set range to 55
# 2024-08-21 11:40:20,264 | INFO |
# Catchment 2927 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2927.shp
# 2024-08-21 11:40:20,280 | INFO | Set range to 55
# 2024-08-21 11:40:23,920 | INFO |
# Catchment 3478 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3478.shp
# 2024-08-21 11:40:23,920 | INFO | Set range to 55
# 2024-08-21 11:40:27,577 | INFO |
# Catchment 3479 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3479.shp
# 2024-08-21 11:40:27,577 | INFO | Set range to 55
# 2024-08-21 11:40:31,217 | INFO |
# Catchment 3481 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3481.shp
# 2024-08-21 11:40:31,217 | INFO | Set range to 55
# 2024-08-21 11:40:34,888 | INFO |
# Catchment 3485 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3485.shp
# 2024-08-21 11:40:34,888 | INFO | Set range to 55
# 2024-08-21 11:40:38,545 | INFO |
# Catchment 3486 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3486.shp
# 2024-08-21 11:40:38,545 | INFO | Set range to 55
# 2024-08-21 11:40:42,202 | INFO |
# Catchment 3487 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3487.shp
# 2024-08-21 11:40:42,202 | INFO | Set range to 55
# 2024-08-21 11:40:46,249 | INFO |
# Catchment 3488 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3488.shp
# 2024-08-21 11:40:46,259 | INFO | Set range to 55
# 2024-08-21 11:40:49,936 | INFO |
# Catchment 3489 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3489.shp
# 2024-08-21 11:40:49,936 | INFO | Set range to 55
# 2024-08-21 11:40:53,608 | INFO |
# Catchment 3490 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3490.shp
# 2024-08-21 11:40:53,608 | INFO | Set range to 55
# 2024-08-21 11:40:57,268 | INFO |
# Catchment 3492 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3492.shp
# 2024-08-21 11:40:57,280 | INFO | Set range to 55
# 2024-08-21 11:41:00,936 | INFO |
# Catchment 3493 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3493.shp
# 2024-08-21 11:41:00,936 | INFO | Set range to 55
# 2024-08-21 11:41:04,580 | INFO |
# Catchment 3494 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3494.shp
# 2024-08-21 11:41:04,580 | INFO | Set range to 55
# 2024-08-21 11:41:08,194 | INFO |
# Catchment 3495 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3495.shp
# 2024-08-21 11:41:08,194 | INFO | Set range to 55
# 2024-08-21 11:41:11,842 | INFO |
# Catchment 3497 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3497.shp
# 2024-08-21 11:41:11,852 | INFO | Set range to 55
# 2024-08-21 11:41:15,530 | INFO |
# Catchment 3498 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3498.shp
# 2024-08-21 11:41:15,530 | INFO | Set range to 55
# 2024-08-21 11:41:19,217 | INFO |
# Catchment 3499 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3499.shp
# 2024-08-21 11:41:19,217 | INFO | Set range to 55
# 2024-08-21 11:41:23,061 | INFO |
# Catchment 3503 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3503.shp
# 2024-08-21 11:41:23,061 | INFO | Set range to 55
# 2024-08-21 11:41:26,686 | INFO |
# Catchment 3504 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3504.shp
# 2024-08-21 11:41:26,686 | INFO | Set range to 55
# 2024-08-21 11:41:30,499 | INFO |
# Catchment 3505 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3505.shp
# 2024-08-21 11:41:30,499 | INFO | Set range to 55
# 2024-08-21 11:41:34,561 | INFO |
# Catchment 3506 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3506.shp
# 2024-08-21 11:41:34,561 | INFO | Set range to 55
# 2024-08-21 11:41:38,280 | INFO |
# Catchment 3507 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3507.shp
# 2024-08-21 11:41:38,295 | INFO | Set range to 55
# 2024-08-21 11:41:41,952 | INFO |
# Catchment 3510 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\3510.shp
# 2024-08-21 11:41:41,952 | INFO | Set range to 55
# 2024-08-21 11:41:45,620 | INFO |
# Catchment 6829 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\6829.shp
# 2024-08-21 11:41:45,624 | INFO | Set range to 55
# 2024-08-21 11:41:49,296 | INFO |
# Catchment 6830 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\6830.shp
# 2024-08-21 11:41:49,296 | INFO | Set range to 55
# 2024-08-21 11:41:52,983 | INFO |
# Catchment 7051 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7051.shp
# 2024-08-21 11:41:52,983 | INFO | Set range to 55
# 2024-08-21 11:41:56,614 | INFO |
# Catchment 7052 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7052.shp
# 2024-08-21 11:41:56,614 | INFO | Set range to 55
# 2024-08-21 11:42:00,276 | INFO |
# Catchment 7053 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7053.shp
# 2024-08-21 11:42:00,280 | INFO | Set range to 55
# 2024-08-21 11:42:04,342 | INFO |
# Catchment 7054 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7054.shp
# 2024-08-21 11:42:04,358 | INFO | Set range to 55
# 2024-08-21 11:42:08,217 | INFO |
# Catchment 7055 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7055.shp
# 2024-08-21 11:42:08,217 | INFO | Set range to 55
# 2024-08-21 11:42:11,869 | INFO |
# Catchment 7056 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7056.shp
# 2024-08-21 11:42:11,869 | INFO | Set range to 55
# 2024-08-21 11:42:15,471 | INFO |
# Catchment 7057 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7057.shp
# 2024-08-21 11:42:15,471 | INFO | Set range to 55
# 2024-08-21 11:42:19,124 | INFO |
# Catchment 7058 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7058.shp
# 2024-08-21 11:42:19,124 | INFO | Set range to 55
# 2024-08-21 11:42:22,760 | INFO |
# Catchment 7059 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7059.shp
# 2024-08-21 11:42:22,760 | INFO | Set range to 55
# 2024-08-21 11:42:26,398 | INFO |
# Catchment 7060 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\7060.shp
# 2024-08-21 11:42:26,420 | INFO | Coordinates an upstream area in the finer grid have been exported to: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\grand_3sec.csv
