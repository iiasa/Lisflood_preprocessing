# %%
"""
# -------------------------------------------------------------------------
# Name:        Use MERIT coordinates of upstream area to create shapefiles
# Purpose:     uses upstream area of MERIT (UPA) and GRDC station data
#              to create shapefiles  from rivernetwork MERIT data
#
# Author:      Peter Burek, Jesús Casado Rodríguez
#
# Created:     15/05/2022
# Copyright:   (c) PB 2022
#
# Updated:     12/08/2024
#
# input:  grdc_MERIT_1.txt  station with new location fitted to merit UPA
# output: grdc_MERIT_2.txt: station with new location fitted to merit UPA and shapefile
#       shapefiles of basins in : ashapex_merit  e.g. grdc_basin_merit_1104800.shp

No: Number from 1 ...
GRDC_No: GRDC number
lat: original latitude from GRDC metafile
lon: original longituted from GRDC metafile
area; provided basin area from GRDC metafile
newlat: corrected latitude based on MERIT UPA dataset
newlon: corrected longitute based on MERIT UPA dataset
newarea: basin area based on MERIT UPA dataset
shapearea: area of the shape calculated with geopandas directly from shape
Lehner_shape_avail: Is there a shapefile from Lehner, 2012 to compare with?
lehner_shapearea: area of the shape (lehner, 2012) calculated with geopandas directly from shape
Indicator: indicator of similarity calculated by intersection / union of newshae and lehner shape - closer to 1 is more similar

"""

import os
os.environ['USE_PYGEOS'] = '0'
import numpy as np
import pandas as pd
import rioxarray
import pyflwdir
from pathlib import Path
from tqdm.auto import tqdm

import warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s | %(levelname)s | %(message)s')
logger = logging.getLogger(__name__)

from utils import catchment_polygon


# CONFIGURATION

# input
STATION_FILE = Path('stations.csv')
LDD_FINE_FILE = Path('../data/danube_fd.tif')

# output folder
SHAPE_FOLDER = Path('./shapefiles/')


# READ INPUT DATA

# read local drainage direction map
ldd_fine = rioxarray.open_rasterio(LDD_FINE_FILE).squeeze(dim='band')
logger.info(f'Map of local drainage directions corretly read: {LDD_FINE_FILE}')

# create river network
fdir_fine = pyflwdir.from_array(ldd_fine.data,
                                ftype='d8', 
                                transform=ldd_fine.rio.transform(),
                                check_ftype=False,
                                latlon=True)

# resolution of the input map
cellsize = np.mean(np.diff(ldd_fine.x)) # degrees
cellsize_arcsec = int(np.round(cellsize * 3600, 0)) # arcsec
suffix_fine = f'{cellsize_arcsec}sec'
logger.info(f'Fine resolution is {cellsize_arcsec} arcseconds')

# read stations text file
stations = pd.read_csv(f'{STATION_FILE.stem}_{suffix_fine}.csv', index_col='ID')
logger.info(f'Table of stations correctly read: {STATION_FILE}')

# output path
SHAPE_FOLDER_FINE = SHAPE_FOLDER / suffix_fine
SHAPE_FOLDER_FINE.mkdir(parents=True, exist_ok=True)


# PROCESSING

for ID, attrs in tqdm(stations.iterrows(), total=stations.shape[0], desc='stations'):
       
    # corrected coordinates
    lat, lon = attrs[[f'lat_{suffix_fine}', f'lon_{suffix_fine}']]
    
    # boolean map of the catchment associated to the corrected coordinates
    logger.debug("basin")
    try:
        basin_arr = fdir_fine.basins(xy=(lon, lat)).astype(np.int32)
    except Exception as e:
        logger.error(f'Conversion to basin not working in catchment {ID}: {e}')
        continue

    # vectorize the boolean map into geopandas
    logger.debug("vectorize")
    basin_gdf = catchment_polygon(basin_arr.astype(np.int32),
                                  transform=ldd_fine.rio.transform(),
                                  crs=ldd_fine.rio.crs,
                                  name='ID')
    basin_gdf['ID'] = ID
    basin_gdf.set_index('ID', inplace=True)
    basin_gdf[attrs.index] = attrs.values

    # export shape file
    output_file = SHAPE_FOLDER_FINE / f'{ID}.shp'
    basin_gdf.to_file(output_file)
    logger.info(f'Catchment {ID} exported as shapefile: {output_file}')
# Out:
# 2024-08-13 13:13:39,460 | INFO | Map of local drainage directions corretly read: ..\data\danube_fd.tif
# 2024-08-13 13:13:48,128 | INFO | Fine resolution is 3 arcseconds
# 2024-08-13 13:13:48,138 | INFO | Table of stations correctly read: stations.csv
# stations:   0%|          | 0/45 [00:00<?, ?it/s]
# 2024-08-13 13:14:06,594 | INFO | Catchment 429 exported as shapefile: shapefiles\3sec\429.shp
# 2024-08-13 13:14:13,468 | INFO | Catchment 436 exported as shapefile: shapefiles\3sec\436.shp
# 2024-08-13 13:14:20,235 | INFO | Catchment 439 exported as shapefile: shapefiles\3sec\439.shp
# 2024-08-13 13:14:26,968 | INFO | Catchment 442 exported as shapefile: shapefiles\3sec\442.shp
# 2024-08-13 13:14:33,765 | INFO | Catchment 444 exported as shapefile: shapefiles\3sec\444.shp
# 2024-08-13 13:14:40,610 | INFO | Catchment 445 exported as shapefile: shapefiles\3sec\445.shp
# 2024-08-13 13:14:47,312 | INFO | Catchment 449 exported as shapefile: shapefiles\3sec\449.shp
# 2024-08-13 13:14:54,026 | INFO | Catchment 450 exported as shapefile: shapefiles\3sec\450.shp
# 2024-08-13 13:15:00,874 | INFO | Catchment 454 exported as shapefile: shapefiles\3sec\454.shp
# 2024-08-13 13:15:07,620 | INFO | Catchment 456 exported as shapefile: shapefiles\3sec\456.shp
# 2024-08-13 13:15:14,374 | INFO | Catchment 460 exported as shapefile: shapefiles\3sec\460.shp
# 2024-08-13 13:15:21,343 | INFO | Catchment 461 exported as shapefile: shapefiles\3sec\461.shp
# 2024-08-13 13:15:28,199 | INFO | Catchment 464 exported as shapefile: shapefiles\3sec\464.shp
# 2024-08-13 13:15:35,070 | INFO | Catchment 465 exported as shapefile: shapefiles\3sec\465.shp
# 2024-08-13 13:15:41,812 | INFO | Catchment 469 exported as shapefile: shapefiles\3sec\469.shp
# 2024-08-13 13:15:48,644 | INFO | Catchment 471 exported as shapefile: shapefiles\3sec\471.shp
# 2024-08-13 13:15:55,405 | INFO | Catchment 475 exported as shapefile: shapefiles\3sec\475.shp
# 2024-08-13 13:16:02,266 | INFO | Catchment 484 exported as shapefile: shapefiles\3sec\484.shp
# 2024-08-13 13:16:09,031 | INFO | Catchment 488 exported as shapefile: shapefiles\3sec\488.shp
# 2024-08-13 13:16:16,031 | INFO | Catchment 489 exported as shapefile: shapefiles\3sec\489.shp
# 2024-08-13 13:16:23,103 | INFO | Catchment 491 exported as shapefile: shapefiles\3sec\491.shp
# 2024-08-13 13:16:30,041 | INFO | Catchment 517 exported as shapefile: shapefiles\3sec\517.shp
# 2024-08-13 13:16:36,606 | INFO | Catchment 529 exported as shapefile: shapefiles\3sec\529.shp
# 2024-08-13 13:16:43,593 | INFO | Catchment 550 exported as shapefile: shapefiles\3sec\550.shp
# 2024-08-13 13:16:50,679 | INFO | Catchment 551 exported as shapefile: shapefiles\3sec\551.shp
# 2024-08-13 13:16:57,638 | INFO | Catchment 553 exported as shapefile: shapefiles\3sec\553.shp
# 2024-08-13 13:17:04,224 | INFO | Catchment 559 exported as shapefile: shapefiles\3sec\559.shp
# 2024-08-13 13:17:11,326 | INFO | Catchment 560 exported as shapefile: shapefiles\3sec\560.shp
# 2024-08-13 13:17:18,124 | INFO | Catchment 562 exported as shapefile: shapefiles\3sec\562.shp
# 2024-08-13 13:17:24,941 | INFO | Catchment 564 exported as shapefile: shapefiles\3sec\564.shp
# 2024-08-13 13:17:32,187 | INFO | Catchment 566 exported as shapefile: shapefiles\3sec\566.shp
# 2024-08-13 13:17:39,005 | INFO | Catchment 578 exported as shapefile: shapefiles\3sec\578.shp
# 2024-08-13 13:17:46,231 | INFO | Catchment 579 exported as shapefile: shapefiles\3sec\579.shp
# 2024-08-13 13:17:52,991 | INFO | Catchment 585 exported as shapefile: shapefiles\3sec\585.shp
# 2024-08-13 13:18:00,826 | INFO | Catchment 591 exported as shapefile: shapefiles\3sec\591.shp
# 2024-08-13 13:18:07,568 | INFO | Catchment 599 exported as shapefile: shapefiles\3sec\599.shp
# 2024-08-13 13:18:15,117 | INFO | Catchment 608 exported as shapefile: shapefiles\3sec\608.shp
# 2024-08-13 13:18:22,800 | INFO | Catchment 612 exported as shapefile: shapefiles\3sec\612.shp
# 2024-08-13 13:18:30,637 | INFO | Catchment 615 exported as shapefile: shapefiles\3sec\615.shp
# 2024-08-13 13:18:37,362 | INFO | Catchment 617 exported as shapefile: shapefiles\3sec\617.shp
# 2024-08-13 13:18:45,089 | INFO | Catchment 626 exported as shapefile: shapefiles\3sec\626.shp
# 2024-08-13 13:18:52,859 | INFO | Catchment 627 exported as shapefile: shapefiles\3sec\627.shp
# 2024-08-13 13:19:00,742 | INFO | Catchment 632 exported as shapefile: shapefiles\3sec\632.shp
# 2024-08-13 13:19:08,530 | INFO | Catchment 633 exported as shapefile: shapefiles\3sec\633.shp
# 2024-08-13 13:19:16,418 | INFO | Catchment 639 exported as shapefile: shapefiles\3sec\639.shp
