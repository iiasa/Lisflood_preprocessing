# %%
"""
# -------------------------------------------------------------------------
# Name:        Shapefile in low-res
# Purpose:     creates shapefiles and a list in lower resolution (5 or 30 arcmin)
#
# Author:      Peter Burek, Jesús Casado Rodríguez
#
# Created:     15/05/2022
# Copyright:   (c) PB 2022
#
# Update:      13/08/2024
#
# input:  results/grdc_shape_allend_1.txt  station with new location fitted to merit UPA from 3_makeshape.py
# output: basins_30min.txt or basins_5min.txt: station with new location fitted to 30 arcmin or 5 arcmin
#          shapefiles of low-res basins in : ashape30min or ashape5min e.g. grdc_basin_30min_basin_1104150.shp

basins_30min.txt
----------------
No: Number from 0 ...
GRDC_No: GRDC number
similarity: similarity of 30min low-res shape with high-res shape from 3arcsec
areaGRDC: area provided by GRDC
area: area from high-res UPA MERIT at pour point
lat: coorected latitude on high-res
lon: corrected longitude on high-res
area30min : area on pour point of best fitting 30arcmin grid cell
lat30min: latitude on 30arcmin
lon30min: longitude on 30arcmin
lat30move: latitude moved to grid cell centre
lon30move: longitude moved to grid cell centre
indloc: locatation of indice which is taken as nbest fit: a 5x5 gridcell surrounding is taken numbered 0-24
upsloc: location (index of 0-24) of best fitting upsstream area
ind:    scoring result for best upstream fitting based on upstream area fitting and shape similarity
ratio: scoring on upstream area fitting between low-res area and high-res area
ups1:   low-res upstream area of best upstream fitting
indshape: scoring on similarity between low-res shape and high res shape
shapeloc: location (index of 0-24) of best fitting shape similarity
ind:    scoring result for best upstream fitting based on upstream area fitting and shape similarity
ratio: scoring on upstream area fitting between low-res area and high-res area
ups1:   low-res upstream area of best shape fitting
indshape: scoring on similarity between low-res shape and high res shape

# uses
# ldd_30min.tif: river network in pcraster format
30min from Döll, P., Lehner, B. (2002): Validation of a new global 30-min drainage direction map. Journal of Hydrology, 258(1-4), 214-23
5min ldd from: Eilander, D., van Verseveld, W., Yamazaki, D., Weerts, A., Winsemius, H. C., and Ward, P. J.: A hydrography upscaling method for scale-invariant parametrization of distributed hydrological models, Hydrol. Earth Syst. Sci., 25, 5287-5313, 10.5194/hess-25-5287-2021, 2021.
# ups_30min.tif: upstream area in [km]

# Shapefiles (smooth) with high resolution from: /ashape2_merit/grdc_basin_merit_


# ----------------------------------------------------------------------
"""

# %%
import os
os.environ['USE_PYGEOS'] = '0'
import numpy as np
import pandas as pd
import geopandas as gpd
import rioxarray
import pyflwdir
from pathlib import Path
from tqdm.auto import tqdm

import warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s | %(levelname)s | %(message)s')
logger = logging.getLogger(__name__)

from lisfloodpreprocessing import Config
from lisfloodpreprocessing.utils import catchment_polygon

# %%
### CONFIGURATION

cfg = Config('Z:/nahaUsers/casadje/datasets/reservoirs/ResOpsES/ancillary/lfcoordinates/config.yml')

# %%
### READ INPUT DATA

# read upstream area map of coarse grid
upstream_coarse = rioxarray.open_rasterio(cfg.UPSTREAM_COARSE).squeeze(dim='band')
logger.info(f'Map of upstream area corretly read: {cfg.UPSTREAM_COARSE}')

# read local drainage direction map
ldd_coarse = rioxarray.open_rasterio(cfg.LDD_COARSE).squeeze(dim='band')
logger.info(f'Map of local drainage directions correctly read: {cfg.LDD_COARSE}')

# create river network
fdir_coarse = pyflwdir.from_array(ldd_coarse.data,
                                  ftype='ldd',
                                  transform=ldd_coarse.rio.transform(),
                                  check_ftype=False,
                                  latlon=True)

# boundaries of the input maps
lon_min, lat_min, lon_max, lat_max = np.round(ldd_coarse.rio.bounds(), 6)

# resolution of the input maps
cellsize = np.round(np.mean(np.diff(ldd_coarse.x)), 6) # degrees
cellsize_arcmin = int(np.round(cellsize * 60, 0)) # arcmin
suffix_coarse = f'{cellsize_arcmin}min'
logger.info(f'Coarse resolution is {cellsize_arcmin} arcminutes')

# %%
# read stations text file
station_file = list(cfg.STATIONS.parent.glob(f'{cfg.STATIONS.stem}*.csv'))[1]
stations = pd.read_csv(station_file, index_col='ID')
logger.info(f'Table of stations correctly read: {station_file}')

# extract resolution of the finer grid
suffixes = [col.split('_')[1] for col in stations.columns if '_' in col]
suffix_fine = sorted(set(suffixes))[0]
cols_fine = [f'{col}_{suffix_fine}' for col in ['lat', 'lon', 'area']]

# add new columns
cols_coarse = [f'{col}_{suffix_coarse}' for col in ['lat', 'lon', 'area']]
stations[cols_coarse] = np.nan

# output folders
SHAPE_FOLDER_FINE = cfg.SHAPE_FOLDER / suffix_fine
SHAPE_FOLDER_COARSE = cfg.SHAPE_FOLDER / suffix_coarse
for folder in [SHAPE_FOLDER_FINE, SHAPE_FOLDER_COARSE]:
    folder.mkdir(parents=True, exist_ok=True)
# Out:
# 2024-08-21 08:42:29,656 | INFO | Table of stations correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\grand_3sec.csv

# %%
### PROCESSING

# search range of 5x5 array -> this is where the best point can be found in the coarse grid
rangexy = np.linspace(-2, 2, 5) * cellsize # arcmin

for ID, attrs in tqdm(stations.iterrows(), total=stations.shape[0], desc='stations'):
    
    # real upstream area
    area_ref = attrs['area']
    
    # coordinates and upstream area in the fine grid
    lat_fine, lon_fine, area_fine = attrs[[f'{col}_{suffix_fine}' for col in ['lat', 'lon', 'area']]]
       
    if (area_ref < cfg.MIN_AREA) or (area_fine < cfg.MIN_AREA):
        logger.info(f'The catchment area of station {ID} is smaller than the minimum of {cfg.MIN_AREA} km2')
        continue
                        
    # import shapefile of catchment polygon
    shapefile = SHAPE_FOLDER_FINE / f'{ID}.shp'
    try:
        basin_fine = gpd.read_file(shapefile)
        logger.info(f'Catchment polygon correctly read: {shapefile}')
    except OSError as e:
        logger.error(f'Error reading {shapefile}: {e}')
        continue
    except Exception as e:  # This will catch other exceptions that might occur.
        logger.error(f'An unexpected error occurred while reading {shapefile}: {e}')
        continue

    # find ratio
    logger.debug('Start search')
    inter_vs_union, area_ratio, area_lisf = [], [], []
    for Δlat in rangexy:
        for Δlon in rangexy:
            lon = lon_fine + Δlon
            lat = lat_fine + Δlat
            basin = catchment_polygon(fdir_coarse.basins(xy=(lon, lat)).astype(np.int32),
                                      transform=ldd_coarse.rio.transform(), 
                                      crs=ldd_coarse.rio.crs)

            # calculate union and intersection of shapes
            intersection = gpd.overlay(basin_fine, basin, how='intersection')
            union = gpd.overlay(basin_fine, basin, how='union')
            inter_vs_union.append(intersection.area.sum() / union.area.sum())

            # get upstream area (km2) of coarse grid (LISFLOOD)
            area = upstream_coarse.sel(x=lon, y=lat, method='nearest').item() * 1e-6
            area_lisf.append(area)

            # ratio between reference and coarse area
            if area_ref == 0 or area == 0:
                ratio = 0
            else:
                ratio = area_ref / area if area_ref < area else area / area_ref
            area_ratio.append(ratio)
    logger.debug('End search')

    # maximum of shape similarity and upstream area accordance
    i_shape = np.argmax(inter_vs_union)
    area_shape = area_lisf[i_shape]
    i_centre = int(len(rangexy)**2 / 2) # middle point
    area_centre = area_lisf[i_centre]           
    # use middle point if errors are small
    abs_error = abs(area_shape - area_centre)
    pct_error = 100 * abs(1 - area_centre / area_shape)
    if (abs_error <= cfg.ABS_ERROR) and (pct_error <= cfg.PCT_ERROR):
        i_shape = i_centre
        area_shape = area_centre

    #i_ratio = np.argmax(area_ratio)          

    # coordinates in the fine resolution
    i = i_shape // len(rangexy)
    j = i_shape % len(rangexy)
    lat = lat_fine + rangexy[i]
    lon = lon_fine + rangexy[j]

    # coordinates and upstream area on coarse resolution
    area = upstream_coarse.sel(x=lon, y=lat, method='nearest')
    area_coarse = area.item() * 1e-6
    lon_coarse = area.x.item()
    lat_coarse = area.y.item()

    # derive catchment polygon from the selected coordinates
    basin_coarse = catchment_polygon(fdir_coarse.basins(xy=(lon_coarse, lat_coarse)).astype(np.int32),
                                     transform=ldd_coarse.rio.transform(), 
                                     crs=ldd_coarse.rio.crs,
                                     name='ID')
    basin_coarse['ID'] = ID
    basin_coarse.set_index('ID', inplace=True)
    basin_coarse[cols_fine] = lat_fine, lon_fine, area_fine
    basin_coarse[cols_coarse] = lat_coarse, lon_coarse, area_coarse

    # export shapefile
    output_shp = SHAPE_FOLDER_COARSE / f'{ID}.shp'
    basin_coarse.to_file(output_shp)
    logger.info(f'Catchment {ID} exported as shapefile: {output_shp}')

    # update new columns in 'stations'
    stations.loc[ID, cols_coarse] = lat_coarse, lon_coarse, area_coarse
# Out:
# stations:   0%|          | 0/253 [00:00<?, ?it/s]
# 2024-08-21 08:43:42,093 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2648.shp
# 2024-08-21 08:43:44,466 | INFO | Catchment 2648 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2648.shp
# 2024-08-21 08:43:44,562 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2649.shp
# 2024-08-21 08:43:46,675 | INFO | Catchment 2649 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2649.shp
# 2024-08-21 08:43:46,750 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2650.shp
# 2024-08-21 08:43:48,956 | INFO | Catchment 2650 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2650.shp
# 2024-08-21 08:43:49,078 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2651.shp
# 2024-08-21 08:43:51,357 | INFO | Catchment 2651 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2651.shp
# 2024-08-21 08:43:51,437 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2652.shp
# 2024-08-21 08:43:53,583 | INFO | Catchment 2652 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2652.shp
# 2024-08-21 08:43:53,656 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2653.shp
# 2024-08-21 08:43:55,921 | INFO | Catchment 2653 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2653.shp
# 2024-08-21 08:43:55,974 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2654.shp
# 2024-08-21 08:43:58,017 | INFO | Catchment 2654 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2654.shp
# 2024-08-21 08:43:58,077 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2656.shp
# 2024-08-21 08:44:00,175 | INFO | Catchment 2656 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2656.shp
# 2024-08-21 08:44:00,218 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2657.shp
# 2024-08-21 08:44:02,296 | INFO | Catchment 2657 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2657.shp
# 2024-08-21 08:44:02,328 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2658.shp
# 2024-08-21 08:44:04,473 | INFO | Catchment 2658 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2658.shp
# 2024-08-21 08:44:04,546 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2660.shp
# 2024-08-21 08:44:06,738 | INFO | Catchment 2660 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2660.shp
# 2024-08-21 08:44:06,781 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2661.shp
# 2024-08-21 08:44:08,856 | INFO | Catchment 2661 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2661.shp
# 2024-08-21 08:44:08,925 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2662.shp
# 2024-08-21 08:44:11,064 | INFO | Catchment 2662 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2662.shp
# 2024-08-21 08:44:11,140 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2663.shp
# 2024-08-21 08:44:13,222 | INFO | Catchment 2663 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2663.shp
# 2024-08-21 08:44:13,250 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2664.shp
# 2024-08-21 08:44:15,359 | INFO | Catchment 2664 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2664.shp
# 2024-08-21 08:44:15,390 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2665.shp
# 2024-08-21 08:44:17,531 | INFO | Catchment 2665 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2665.shp
# 2024-08-21 08:44:17,568 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2666.shp
# 2024-08-21 08:44:19,656 | INFO | Catchment 2666 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2666.shp
# 2024-08-21 08:44:19,671 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2667.shp
# 2024-08-21 08:44:21,791 | INFO | Catchment 2667 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2667.shp
# 2024-08-21 08:44:21,832 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2668.shp
# 2024-08-21 08:44:24,004 | INFO | Catchment 2668 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2668.shp
# 2024-08-21 08:44:24,031 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2669.shp
# 2024-08-21 08:44:26,111 | INFO | Catchment 2669 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2669.shp
# 2024-08-21 08:44:26,140 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2670.shp
# 2024-08-21 08:44:28,217 | INFO | Catchment 2670 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2670.shp
# 2024-08-21 08:44:28,257 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2671.shp
# 2024-08-21 08:44:30,372 | INFO | Catchment 2671 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2671.shp
# 2024-08-21 08:44:30,405 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2672.shp
# 2024-08-21 08:44:32,746 | INFO | Catchment 2672 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2672.shp
# 2024-08-21 08:44:32,781 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2673.shp
# 2024-08-21 08:44:34,905 | INFO | Catchment 2673 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2673.shp
# 2024-08-21 08:44:34,936 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2674.shp
# 2024-08-21 08:44:37,157 | INFO | Catchment 2674 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2674.shp
# 2024-08-21 08:44:37,187 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2675.shp
# 2024-08-21 08:44:39,319 | INFO | Catchment 2675 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2675.shp
# 2024-08-21 08:44:39,359 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2676.shp
# 2024-08-21 08:44:41,504 | INFO | Catchment 2676 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2676.shp
# 2024-08-21 08:44:41,535 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2677.shp
# 2024-08-21 08:44:43,671 | INFO | Catchment 2677 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2677.shp
# 2024-08-21 08:44:43,718 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2678.shp
# 2024-08-21 08:44:45,911 | INFO | Catchment 2678 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2678.shp
# 2024-08-21 08:44:45,937 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2679.shp
# 2024-08-21 08:44:48,052 | INFO | Catchment 2679 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2679.shp
# 2024-08-21 08:44:48,079 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2680.shp
# 2024-08-21 08:44:50,148 | INFO | Catchment 2680 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2680.shp
# 2024-08-21 08:44:50,174 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2681.shp
# 2024-08-21 08:44:52,232 | INFO | Catchment 2681 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2681.shp
# 2024-08-21 08:44:52,263 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2682.shp
# 2024-08-21 08:44:54,302 | INFO | Catchment 2682 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2682.shp
# 2024-08-21 08:44:54,343 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2683.shp
# 2024-08-21 08:44:56,687 | INFO | Catchment 2683 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2683.shp
# 2024-08-21 08:44:56,718 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2684.shp
# 2024-08-21 08:44:58,906 | INFO | Catchment 2684 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2684.shp
# 2024-08-21 08:44:58,937 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2685.shp
# 2024-08-21 08:45:01,125 | INFO | Catchment 2685 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2685.shp
# 2024-08-21 08:45:01,140 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2686.shp
# 2024-08-21 08:45:03,999 | INFO | Catchment 2686 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2686.shp
# 2024-08-21 08:45:04,062 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2687.shp
# 2024-08-21 08:45:06,687 | INFO | Catchment 2687 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2687.shp
# 2024-08-21 08:45:06,750 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2688.shp
# 2024-08-21 08:45:08,868 | INFO | Catchment 2688 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2688.shp
# 2024-08-21 08:45:08,930 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2689.shp
# 2024-08-21 08:45:11,148 | INFO | Catchment 2689 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2689.shp
# 2024-08-21 08:45:11,202 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2690.shp
# 2024-08-21 08:45:13,984 | INFO | Catchment 2690 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2690.shp
# 2024-08-21 08:45:14,035 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2691.shp
# 2024-08-21 08:45:16,215 | INFO | Catchment 2691 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2691.shp
# 2024-08-21 08:45:16,249 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2692.shp
# 2024-08-21 08:45:18,374 | INFO | Catchment 2692 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2692.shp
# 2024-08-21 08:45:18,406 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2693.shp
# 2024-08-21 08:45:20,463 | INFO | Catchment 2693 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2693.shp
# 2024-08-21 08:45:20,499 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2694.shp
# 2024-08-21 08:45:23,343 | INFO | Catchment 2694 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2694.shp
# 2024-08-21 08:45:23,406 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2695.shp
# 2024-08-21 08:45:25,515 | INFO | Catchment 2695 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2695.shp
# 2024-08-21 08:45:25,609 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2696.shp
# 2024-08-21 08:45:27,724 | INFO | Catchment 2696 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2696.shp
# 2024-08-21 08:45:27,796 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2697.shp
# 2024-08-21 08:45:30,046 | INFO | Catchment 2697 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2697.shp
# 2024-08-21 08:45:30,071 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2699.shp
# 2024-08-21 08:45:32,184 | INFO | Catchment 2699 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2699.shp
# 2024-08-21 08:45:32,203 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2700.shp
# 2024-08-21 08:45:34,343 | INFO | Catchment 2700 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2700.shp
# 2024-08-21 08:45:34,390 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2701.shp
# 2024-08-21 08:45:37,421 | INFO | Catchment 2701 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2701.shp
# 2024-08-21 08:45:37,468 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2702.shp
# 2024-08-21 08:45:39,562 | INFO | Catchment 2702 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2702.shp
# 2024-08-21 08:45:39,593 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2703.shp
# 2024-08-21 08:45:41,718 | INFO | Catchment 2703 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2703.shp
# 2024-08-21 08:45:41,807 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2704.shp
# 2024-08-21 08:45:43,884 | INFO | Catchment 2704 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2704.shp
# 2024-08-21 08:45:43,924 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2706.shp
# 2024-08-21 08:45:46,030 | INFO | Catchment 2706 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2706.shp
# 2024-08-21 08:45:46,113 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2707.shp
# 2024-08-21 08:45:48,283 | INFO | Catchment 2707 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2707.shp
# 2024-08-21 08:45:48,343 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2708.shp
# 2024-08-21 08:45:50,546 | INFO | Catchment 2708 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2708.shp
# 2024-08-21 08:45:50,578 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2709.shp
# 2024-08-21 08:45:52,718 | INFO | Catchment 2709 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2709.shp
# 2024-08-21 08:45:52,786 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2710.shp
# 2024-08-21 08:45:54,991 | INFO | Catchment 2710 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2710.shp
# 2024-08-21 08:45:55,109 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2711.shp
# 2024-08-21 08:45:57,297 | INFO | Catchment 2711 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2711.shp
# 2024-08-21 08:45:57,359 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2712.shp
# 2024-08-21 08:45:59,484 | INFO | Catchment 2712 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2712.shp
# 2024-08-21 08:45:59,563 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2722.shp
# 2024-08-21 08:46:01,671 | INFO | Catchment 2722 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2722.shp
# 2024-08-21 08:46:01,749 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2723.shp
# 2024-08-21 08:46:05,499 | INFO | Catchment 2723 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2723.shp
# 2024-08-21 08:46:05,562 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2725.shp
# 2024-08-21 08:46:08,110 | INFO | Catchment 2725 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2725.shp
# 2024-08-21 08:46:08,140 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2726.shp
# 2024-08-21 08:46:10,271 | INFO | Catchment 2726 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2726.shp
# 2024-08-21 08:46:10,328 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2728.shp
# 2024-08-21 08:46:14,173 | INFO | Catchment 2728 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2728.shp
# 2024-08-21 08:46:14,203 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2731.shp
# 2024-08-21 08:46:16,390 | INFO | Catchment 2731 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2731.shp
# 2024-08-21 08:46:16,437 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2733.shp
# 2024-08-21 08:46:18,952 | INFO | Catchment 2733 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2733.shp
# 2024-08-21 08:46:18,999 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2734.shp
# 2024-08-21 08:46:21,265 | INFO | Catchment 2734 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2734.shp
# 2024-08-21 08:46:21,328 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2735.shp
# 2024-08-21 08:46:24,749 | INFO | Catchment 2735 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2735.shp
# 2024-08-21 08:46:24,780 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2743.shp
# 2024-08-21 08:46:26,921 | INFO | Catchment 2743 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2743.shp
# 2024-08-21 08:46:27,046 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2744.shp
# 2024-08-21 08:46:30,468 | INFO | Catchment 2744 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2744.shp
# 2024-08-21 08:46:30,531 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2745.shp
# 2024-08-21 08:46:32,636 | INFO | Catchment 2745 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2745.shp
# 2024-08-21 08:46:32,718 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2746.shp
# 2024-08-21 08:46:34,812 | INFO | Catchment 2746 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2746.shp
# 2024-08-21 08:46:34,875 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2747.shp
# 2024-08-21 08:46:36,999 | INFO | Catchment 2747 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2747.shp
# 2024-08-21 08:46:37,062 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2749.shp
# 2024-08-21 08:46:39,109 | INFO | Catchment 2749 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2749.shp
# 2024-08-21 08:46:39,183 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2750.shp
# 2024-08-21 08:46:41,406 | INFO | Catchment 2750 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2750.shp
# 2024-08-21 08:46:41,508 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2751.shp
# 2024-08-21 08:46:43,726 | INFO | Catchment 2751 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2751.shp
# 2024-08-21 08:46:43,812 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2752.shp
# 2024-08-21 08:46:45,937 | INFO | Catchment 2752 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2752.shp
# 2024-08-21 08:46:46,015 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2753.shp
# 2024-08-21 08:46:48,187 | INFO | Catchment 2753 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2753.shp
# 2024-08-21 08:46:48,249 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2754.shp
# 2024-08-21 08:46:50,581 | INFO | Catchment 2754 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2754.shp
# 2024-08-21 08:46:50,671 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2755.shp
# 2024-08-21 08:46:52,866 | INFO | Catchment 2755 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2755.shp
# 2024-08-21 08:46:52,905 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2756.shp
# 2024-08-21 08:46:55,129 | INFO | Catchment 2756 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2756.shp
# 2024-08-21 08:46:55,187 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2757.shp
# 2024-08-21 08:46:57,359 | INFO | Catchment 2757 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2757.shp
# 2024-08-21 08:46:57,390 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2758.shp
# 2024-08-21 08:46:59,546 | INFO | Catchment 2758 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2758.shp
# 2024-08-21 08:46:59,624 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2759.shp
# 2024-08-21 08:47:01,789 | INFO | Catchment 2759 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2759.shp
# 2024-08-21 08:47:01,843 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2761.shp
# 2024-08-21 08:47:03,968 | INFO | Catchment 2761 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2761.shp
# 2024-08-21 08:47:04,046 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2762.shp
# 2024-08-21 08:47:06,298 | INFO | Catchment 2762 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2762.shp
# 2024-08-21 08:47:06,422 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2763.shp
# 2024-08-21 08:47:08,453 | INFO | Catchment 2763 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2763.shp
# 2024-08-21 08:47:08,562 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2764.shp
# 2024-08-21 08:47:10,687 | INFO | Catchment 2764 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2764.shp
# 2024-08-21 08:47:10,781 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2765.shp
# 2024-08-21 08:47:12,861 | INFO | Catchment 2765 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2765.shp
# 2024-08-21 08:47:12,947 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2766.shp
# 2024-08-21 08:47:15,113 | INFO | Catchment 2766 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2766.shp
# 2024-08-21 08:47:15,162 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2767.shp
# 2024-08-21 08:47:17,718 | INFO | Catchment 2767 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2767.shp
# 2024-08-21 08:47:17,781 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2768.shp
# 2024-08-21 08:47:20,034 | INFO | Catchment 2768 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2768.shp
# 2024-08-21 08:47:20,093 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2769.shp
# 2024-08-21 08:47:22,640 | INFO | Catchment 2769 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2769.shp
# 2024-08-21 08:47:22,749 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2770.shp
# 2024-08-21 08:47:25,062 | INFO | Catchment 2770 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2770.shp
# 2024-08-21 08:47:25,124 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2771.shp
# 2024-08-21 08:47:27,296 | INFO | Catchment 2771 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2771.shp
# 2024-08-21 08:47:27,484 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2772.shp
# 2024-08-21 08:47:30,079 | INFO | Catchment 2772 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2772.shp
# 2024-08-21 08:47:30,124 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2774.shp
# 2024-08-21 08:47:32,374 | INFO | Catchment 2774 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2774.shp
# 2024-08-21 08:47:32,484 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2779.shp
# 2024-08-21 08:47:34,671 | INFO | Catchment 2779 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2779.shp
# 2024-08-21 08:47:34,702 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2780.shp
# 2024-08-21 08:47:36,843 | INFO | Catchment 2780 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2780.shp
# 2024-08-21 08:47:36,906 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2781.shp
# 2024-08-21 08:47:39,015 | INFO | Catchment 2781 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2781.shp
# 2024-08-21 08:47:39,074 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2782.shp
# 2024-08-21 08:47:41,259 | INFO | Catchment 2782 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2782.shp
# 2024-08-21 08:47:41,321 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2783.shp
# 2024-08-21 08:47:43,523 | INFO | Catchment 2783 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2783.shp
# 2024-08-21 08:47:43,625 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2785.shp
# 2024-08-21 08:47:45,834 | INFO | Catchment 2785 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2785.shp
# 2024-08-21 08:47:45,968 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2786.shp
# 2024-08-21 08:47:48,057 | INFO | Catchment 2786 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2786.shp
# 2024-08-21 08:47:48,173 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2787.shp
# 2024-08-21 08:47:50,343 | INFO | Catchment 2787 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2787.shp
# 2024-08-21 08:47:50,424 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2788.shp
# 2024-08-21 08:47:52,562 | INFO | Catchment 2788 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2788.shp
# 2024-08-21 08:47:52,625 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2789.shp
# 2024-08-21 08:47:54,928 | INFO | Catchment 2789 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2789.shp
# 2024-08-21 08:47:55,011 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2793.shp
# 2024-08-21 08:47:58,516 | INFO | Catchment 2793 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2793.shp
# 2024-08-21 08:47:58,635 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2794.shp
# 2024-08-21 08:48:01,860 | INFO | Catchment 2794 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2794.shp
# 2024-08-21 08:48:01,945 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2795.shp
# 2024-08-21 08:48:05,344 | INFO | Catchment 2795 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2795.shp
# 2024-08-21 08:48:05,391 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2796.shp
# 2024-08-21 08:48:07,445 | INFO | Catchment 2796 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2796.shp
# 2024-08-21 08:48:07,531 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2797.shp
# 2024-08-21 08:48:11,025 | INFO | Catchment 2797 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2797.shp
# 2024-08-21 08:48:11,124 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2798.shp
# 2024-08-21 08:48:14,437 | INFO | Catchment 2798 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2798.shp
# 2024-08-21 08:48:14,499 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2799.shp
# 2024-08-21 08:48:17,553 | INFO | Catchment 2799 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2799.shp
# 2024-08-21 08:48:17,640 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2800.shp
# 2024-08-21 08:48:21,624 | INFO | Catchment 2800 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2800.shp
# 2024-08-21 08:48:21,656 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2801.shp
# 2024-08-21 08:48:24,281 | INFO | Catchment 2801 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2801.shp
# 2024-08-21 08:48:24,390 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2802.shp
# 2024-08-21 08:48:27,171 | INFO | Catchment 2802 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2802.shp
# 2024-08-21 08:48:27,280 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2803.shp
# 2024-08-21 08:48:30,937 | INFO | Catchment 2803 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2803.shp
# 2024-08-21 08:48:30,984 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2804.shp
# 2024-08-21 08:48:33,128 | INFO | Catchment 2804 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2804.shp
# 2024-08-21 08:48:33,172 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2805.shp
# 2024-08-21 08:48:35,612 | INFO | Catchment 2805 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2805.shp
# 2024-08-21 08:48:35,707 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2807.shp
# 2024-08-21 08:48:38,062 | INFO | Catchment 2807 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2807.shp
# 2024-08-21 08:48:38,124 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2810.shp
# 2024-08-21 08:48:40,195 | INFO | Catchment 2810 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2810.shp
# 2024-08-21 08:48:40,241 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2811.shp
# 2024-08-21 08:48:43,390 | INFO | Catchment 2811 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2811.shp
# 2024-08-21 08:48:43,515 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2812.shp
# 2024-08-21 08:48:45,671 | INFO | Catchment 2812 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2812.shp
# 2024-08-21 08:48:45,734 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2813.shp
# 2024-08-21 08:48:47,890 | INFO | Catchment 2813 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2813.shp
# 2024-08-21 08:48:47,968 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2815.shp
# 2024-08-21 08:48:50,656 | INFO | Catchment 2815 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2815.shp
# 2024-08-21 08:48:50,718 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2816.shp
# 2024-08-21 08:48:52,828 | INFO | Catchment 2816 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2816.shp
# 2024-08-21 08:48:52,890 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2817.shp
# 2024-08-21 08:48:55,708 | INFO | Catchment 2817 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2817.shp
# 2024-08-21 08:48:55,761 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2818.shp
# 2024-08-21 08:48:58,620 | INFO | Catchment 2818 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2818.shp
# 2024-08-21 08:48:58,655 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2820.shp
# 2024-08-21 08:49:00,855 | INFO | Catchment 2820 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2820.shp
# 2024-08-21 08:49:00,906 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2821.shp
# 2024-08-21 08:49:03,083 | INFO | Catchment 2821 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2821.shp
# 2024-08-21 08:49:03,124 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2822.shp
# 2024-08-21 08:49:06,421 | INFO | Catchment 2822 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2822.shp
# 2024-08-21 08:49:06,468 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2823.shp
# 2024-08-21 08:49:09,375 | INFO | Catchment 2823 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2823.shp
# 2024-08-21 08:49:09,421 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2824.shp
# 2024-08-21 08:49:11,689 | INFO | Catchment 2824 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2824.shp
# 2024-08-21 08:49:11,734 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2825.shp
# 2024-08-21 08:49:14,593 | INFO | Catchment 2825 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2825.shp
# 2024-08-21 08:49:14,609 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2826.shp
# 2024-08-21 08:49:16,781 | INFO | Catchment 2826 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2826.shp
# 2024-08-21 08:49:16,837 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2830.shp
# 2024-08-21 08:49:20,032 | INFO | Catchment 2830 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2830.shp
# 2024-08-21 08:49:20,062 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2831.shp
# 2024-08-21 08:49:22,218 | INFO | Catchment 2831 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2831.shp
# 2024-08-21 08:49:22,249 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2832.shp
# 2024-08-21 08:49:24,750 | INFO | Catchment 2832 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2832.shp
# 2024-08-21 08:49:24,787 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2833.shp
# 2024-08-21 08:49:27,281 | INFO | Catchment 2833 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2833.shp
# 2024-08-21 08:49:27,296 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2834.shp
# 2024-08-21 08:49:29,494 | INFO | Catchment 2834 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2834.shp
# 2024-08-21 08:49:29,546 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2835.shp
# 2024-08-21 08:49:33,155 | INFO | Catchment 2835 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2835.shp
# 2024-08-21 08:49:33,171 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2836.shp
# 2024-08-21 08:49:35,437 | INFO | Catchment 2836 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2836.shp
# 2024-08-21 08:49:35,499 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2838.shp
# 2024-08-21 08:49:37,671 | INFO | Catchment 2838 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2838.shp
# 2024-08-21 08:49:37,749 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2839.shp
# 2024-08-21 08:49:39,812 | INFO | Catchment 2839 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2839.shp
# 2024-08-21 08:49:39,859 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2840.shp
# 2024-08-21 08:49:41,937 | INFO | Catchment 2840 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2840.shp
# 2024-08-21 08:49:42,020 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2842.shp
# 2024-08-21 08:49:44,093 | INFO | Catchment 2842 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2842.shp
# 2024-08-21 08:49:44,171 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2843.shp
# 2024-08-21 08:49:46,361 | INFO | Catchment 2843 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2843.shp
# 2024-08-21 08:49:46,421 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2844.shp
# 2024-08-21 08:49:48,562 | INFO | Catchment 2844 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2844.shp
# 2024-08-21 08:49:48,624 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2846.shp
# 2024-08-21 08:49:50,781 | INFO | Catchment 2846 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2846.shp
# 2024-08-21 08:49:50,865 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2848.shp
# 2024-08-21 08:49:53,098 | INFO | Catchment 2848 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2848.shp
# 2024-08-21 08:49:53,187 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2849.shp
# 2024-08-21 08:49:55,406 | INFO | Catchment 2849 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2849.shp
# 2024-08-21 08:49:55,468 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2850.shp
# 2024-08-21 08:49:57,696 | INFO | Catchment 2850 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2850.shp
# 2024-08-21 08:49:57,734 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2851.shp
# 2024-08-21 08:50:00,219 | INFO | Catchment 2851 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2851.shp
# 2024-08-21 08:50:00,265 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2853.shp
# 2024-08-21 08:50:02,390 | INFO | Catchment 2853 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2853.shp
# 2024-08-21 08:50:02,443 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2855.shp
# 2024-08-21 08:50:04,769 | INFO | Catchment 2855 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2855.shp
# 2024-08-21 08:50:04,812 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2856.shp
# 2024-08-21 08:50:07,354 | INFO | Catchment 2856 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2856.shp
# 2024-08-21 08:50:07,374 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2858.shp
# 2024-08-21 08:50:09,631 | INFO | Catchment 2858 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2858.shp
# 2024-08-21 08:50:09,671 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2860.shp
# 2024-08-21 08:50:11,832 | INFO | Catchment 2860 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2860.shp
# 2024-08-21 08:50:11,953 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2861.shp
# 2024-08-21 08:50:14,137 | INFO | Catchment 2861 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2861.shp
# 2024-08-21 08:50:14,187 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2862.shp
# 2024-08-21 08:50:16,312 | INFO | Catchment 2862 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2862.shp
# 2024-08-21 08:50:16,375 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2863.shp
# 2024-08-21 08:50:18,640 | INFO | Catchment 2863 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2863.shp
# 2024-08-21 08:50:18,703 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2864.shp
# 2024-08-21 08:50:21,079 | INFO | Catchment 2864 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2864.shp
# 2024-08-21 08:50:21,140 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2865.shp
# 2024-08-21 08:50:23,299 | INFO | Catchment 2865 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2865.shp
# 2024-08-21 08:50:23,390 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2866.shp
# 2024-08-21 08:50:25,499 | INFO | Catchment 2866 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2866.shp
# 2024-08-21 08:50:25,547 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2867.shp
# 2024-08-21 08:50:27,831 | INFO | Catchment 2867 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2867.shp
# 2024-08-21 08:50:27,898 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2868.shp
# 2024-08-21 08:50:30,312 | INFO | Catchment 2868 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2868.shp
# 2024-08-21 08:50:30,422 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2869.shp
# 2024-08-21 08:50:33,718 | INFO | Catchment 2869 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2869.shp
# 2024-08-21 08:50:33,795 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2870.shp
# 2024-08-21 08:50:36,000 | INFO | Catchment 2870 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2870.shp
# 2024-08-21 08:50:36,109 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2871.shp
# 2024-08-21 08:50:38,797 | INFO | Catchment 2871 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2871.shp
# 2024-08-21 08:50:38,890 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2872.shp
# 2024-08-21 08:50:41,155 | INFO | Catchment 2872 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2872.shp
# 2024-08-21 08:50:41,281 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2873.shp
# 2024-08-21 08:50:44,781 | INFO | Catchment 2873 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2873.shp
# 2024-08-21 08:50:44,851 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2875.shp
# 2024-08-21 08:50:47,031 | INFO | Catchment 2875 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2875.shp
# 2024-08-21 08:50:47,109 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2876.shp
# 2024-08-21 08:50:49,429 | INFO | Catchment 2876 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2876.shp
# 2024-08-21 08:50:49,458 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2878.shp
# 2024-08-21 08:50:51,888 | INFO | Catchment 2878 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2878.shp
# 2024-08-21 08:50:51,958 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2879.shp
# 2024-08-21 08:50:54,093 | INFO | Catchment 2879 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2879.shp
# 2024-08-21 08:50:54,125 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2880.shp
# 2024-08-21 08:50:56,250 | INFO | Catchment 2880 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2880.shp
# 2024-08-21 08:50:56,296 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2882.shp
# 2024-08-21 08:50:59,781 | INFO | Catchment 2882 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2882.shp
# 2024-08-21 08:50:59,859 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2883.shp
# 2024-08-21 08:51:02,001 | INFO | Catchment 2883 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2883.shp
# 2024-08-21 08:51:02,062 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2884.shp
# 2024-08-21 08:51:04,141 | INFO | Catchment 2884 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2884.shp
# 2024-08-21 08:51:04,187 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2885.shp
# 2024-08-21 08:51:06,363 | INFO | Catchment 2885 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2885.shp
# 2024-08-21 08:51:06,390 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2886.shp
# 2024-08-21 08:51:08,562 | INFO | Catchment 2886 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2886.shp
# 2024-08-21 08:51:08,593 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2887.shp
# 2024-08-21 08:51:10,657 | INFO | Catchment 2887 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2887.shp
# 2024-08-21 08:51:10,687 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2888.shp
# 2024-08-21 08:51:12,828 | INFO | Catchment 2888 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2888.shp
# 2024-08-21 08:51:12,859 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2889.shp
# 2024-08-21 08:51:15,109 | INFO | Catchment 2889 exported as shapefile: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\1min\2889.shp
# 2024-08-21 08:51:15,124 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2891.shp

# %%
# export results
stations.sort_index(axis=1, inplace=True)
output_csv = f'{Path(STATION_FILE).stem}_{suffix_coarse}.csv'
stations.to_csv(output_csv)
logger.info(f'Results have been exported to: {output_csv}')
# Out:
# stations:   0%|          | 0/253 [00:00<?, ?it/s]
# 2024-08-21 08:42:30,515 | INFO | Catchment polygon correctly read: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsES\ancillary\lfcoordinates\shapefiles\3sec\2648.shp
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [32], line 66
#      64 abs_error = abs(area_shape - area_centre)
#      65 pct_error = 100 * abs(1 - area_centre / area_shape)
# ---> 66 if (abs_error <= ABS_ERROR) and (pct_error <= PCT_ERROR):
#      67     i_shape = i_centre
#      68     area_shape = area_centre
#
# NameError: name 'ABS_ERROR' is not defined

# %%
ID, lon, lat
# Out:
# (2648, 43.443332999999996, -6.755001)

# %%
stations.head()
# Out:
#       area  area_3sec        lat  lat_3sec       lon   lon_3sec  lat_1min  \
# ID
# 2648  2506     2498.0  43.476871 -6.721667 -6.721875  43.476667       NaN
# 2649   134      132.0  43.461095 -7.827500 -7.827105  43.460833       NaN
# 2650   396      396.0  43.405480 -8.010000 -8.009740  43.406667       NaN
# 2651  2292     2286.0  43.385655 -6.827500 -6.827365  43.385833       NaN
# 2652   248      222.0  43.281609 -8.296667 -8.296299  43.281667       NaN
#
#       lon_1min  area_1min
# ID
# 2648       NaN        NaN
# 2649       NaN        NaN
# 2650       NaN        NaN
# 2651       NaN        NaN
# 2652       NaN        NaN
