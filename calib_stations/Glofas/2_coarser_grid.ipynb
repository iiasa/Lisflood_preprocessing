# %%
"""
# -------------------------------------------------------------------------
# Name:        Shapefile in low-res
# Purpose:     creates shapefiles and a list in lower resolution (5 or 30 arcmin)
#
# Author:      Peter Burek, Jesús Casado Rodríguez
#
# Created:     15/05/2022
# Copyright:   (c) PB 2022
#
# Update:      13/08/2024
#
# input:  results/grdc_shape_allend_1.txt  station with new location fitted to merit UPA from 3_makeshape.py
# output: basins_30min.txt or basins_5min.txt: station with new location fitted to 30 arcmin or 5 arcmin
#          shapefiles of low-res basins in : ashape30min or ashape5min e.g. grdc_basin_30min_basin_1104150.shp

basins_30min.txt
----------------
No: Number from 0 ...
GRDC_No: GRDC number
similarity: similarity of 30min low-res shape with high-res shape from 3arcsec
areaGRDC: area provided by GRDC
area: area from high-res UPA MERIT at pour point
lat: coorected latitude on high-res
lon: corrected longitude on high-res
area30min : area on pour point of best fitting 30arcmin grid cell
lat30min: latitude on 30arcmin
lon30min: longitude on 30arcmin
lat30move: latitude moved to grid cell centre
lon30move: longitude moved to grid cell centre
indloc: locatation of indice which is taken as nbest fit: a 5x5 gridcell surrounding is taken numbered 0-24
upsloc: location (index of 0-24) of best fitting upsstream area
ind:    scoring result for best upstream fitting based on upstream area fitting and shape similarity
ratio: scoring on upstream area fitting between low-res area and high-res area
ups1:   low-res upstream area of best upstream fitting
indshape: scoring on similarity between low-res shape and high res shape
shapeloc: location (index of 0-24) of best fitting shape similarity
ind:    scoring result for best upstream fitting based on upstream area fitting and shape similarity
ratio: scoring on upstream area fitting between low-res area and high-res area
ups1:   low-res upstream area of best shape fitting
indshape: scoring on similarity between low-res shape and high res shape

# uses
# ldd_30min.tif: river network in pcraster format
30min from Döll, P., Lehner, B. (2002): Validation of a new global 30-min drainage direction map. Journal of Hydrology, 258(1-4), 214-23
5min ldd from: Eilander, D., van Verseveld, W., Yamazaki, D., Weerts, A., Winsemius, H. C., and Ward, P. J.: A hydrography upscaling method for scale-invariant parametrization of distributed hydrological models, Hydrol. Earth Syst. Sci., 25, 5287-5313, 10.5194/hess-25-5287-2021, 2021.
# ups_30min.tif: upstream area in [km]

# Shapefiles (smooth) with high resolution from: /ashape2_merit/grdc_basin_merit_


# ----------------------------------------------------------------------
"""

import os
os.environ['USE_PYGEOS'] = '0'
import numpy as np
import pandas as pd
import geopandas as gpd
import rioxarray
import pyflwdir
from pathlib import Path
from tqdm.auto import tqdm

import warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s | %(levelname)s | %(message)s')
logger = logging.getLogger(__name__)

from utils import catchment_polygon


### CONFIGURATION

# input data
STATION_FILE = 'stations_MERIT.csv' # output of step 1
LDD_COARSE_FILE = "ldd_3min.tif"
UPSTREAM_COARSE_FILE = "upArea_repaired.nc"

# output folder
SHAPE_FOLDER = Path('./shapefiles/')

# conditions
MIN_AREA = 100 # km2
ABS_ERROR = 50 # km2
PCT_ERROR = 1 # %


### READ INPUT DATA

# read upstream area map of coarse grid
upstream_coarse = rioxarray.open_rasterio(UPSTREAM_COARSE_FILE).squeeze(dim='band')
logger.info(f'Map of upstream area corretly read: {UPSTREAM_COARSE_FILE}')

# read local drainage direction map
ldd_coarse = rioxarray.open_rasterio(LDD_COARSE_FILE).squeeze(dim='band')
logger.info(f'Map of local drainage directions correctly read: {LDD_COARSE_FILE}')

# create river network
fdir_coarse = pyflwdir.from_array(ldd_coarse.data,
                          ftype='ldd',
                          transform=ldd_coarse.rio.transform(),
                          check_ftype=False,
                          latlon=True)

# boundaries of the input maps
lon_min, lat_min, lon_max, lat_max = np.round(ldd_coarse.rio.bounds(), 6)

# resolution of the input maps
cellsize = np.round(np.mean(np.diff(ldd_coarse.x)), 6) # degrees
cellsize_arcmin = int(np.round(cellsize * 60, 0)) # arcmin
suffix_coarse = f'{cellsize_arcmin}min'
logger.info(f'Coarse resolution is {cellsize_arcmin} arcminutes')

# read stations text file
stations = pd.read_csv(STATION_FILE, index_col='ID')
logger.info(f'Table of stations correctly read: {STATION_FILE}')

# extract resolution of the finer grid
suffixes = [col.split('_')[1] for col in stations.columns if '_' in col]
suffix_fine = sorted(set(suffixes))[0]
cols_fine = [f'{col}_{suffix_fine}' for col in ['lat', 'lon', 'area']]

# add new columns
cols_coarse = [f'{col}_{suffix_coarse}' for col in ['lat', 'lon', 'area']]
stations[cols_coarse] = np.nan

# output folders
SHAPE_FOLDER_FINE = SHAPE_FOLDER / suffix_fine
SHAPE_FOLDER_COARSE = SHAPE_FOLDER / suffix_coarse
for folder in [SHAPE_FOLDER_FINE, SHAPE_FOLDER_COARSE]:
    folder.mkdir(parents=True, exist_ok=True)


### PROCESSING

# search range of 5x5 array -> this is where the best point can be found in the coarse grid
rangexy = np.linspace(-2, 2, 5) * cellsize # arcmin

for ID, attrs in tqdm(stations.iterrows(), total=stations.shape[0], desc='stations'):
    
    # real upstream area
    area_ref = attrs['area']
    
    # coordinates and upstream area in the fine grid
    lat_fine, lon_fine, area_fine = attrs[[f'{col}_{suffix_fine}' for col in ['lat', 'lon', 'area']]]
       
    if (area_ref < MIN_AREA) or (area_fine < MIN_AREA):
        logger.info(f'The catchment area of station {ID} is smaller than the minimum of {MIN_AREA} km2')
        continue
                        
    # import shapefile of catchment polygon
    shapefile = SHAPE_FOLDER_FINE / f'{ID}.shp'
    try:
        basin_fine = gpd.read_file(shapefile)
        logger.info(f'Catchment polygon correctly read: {shapefile}')
    except OSError as e:
        logger.error(f'Error reading {shapefile}: {e}')
        continue
    except Exception as e:  # This will catch other exceptions that might occur.
        logger.error(f'An unexpected error occurred while reading {shapefile}: {e}')
        continue

    # find ratio
    logger.debug('Start search')
    inter_vs_union, area_ratio, area_lisf = [], [], []
    for Δlat in rangexy:
        for Δlon in rangexy:
            lon = lon_fine + Δlon
            lat = lat_fine + Δlat
            basin = catchment_polygon(fdir_coarse.basins(xy=(lon, lat)).astype(np.int32),
                                      transform=ldd_coarse.rio.transform(), 
                                      crs=ldd_coarse.rio.crs)

            # calculate union and intersection of shapes
            intersection = gpd.overlay(basin_fine, basin, how='intersection')
            union = gpd.overlay(basin_fine, basin, how='union')
            inter_vs_union.append(intersection.area.sum() / union.area.sum())

            # get upstream area (km2) of coarse grid (LISFLOOD)
            area = upstream_coarse.sel(x=lon, y=lat, method='nearest').item() * 1e-6
            area_lisf.append(area)

            # ratio between reference and coarse area
            if area_ref == 0 or area == 0:
                ratio = 0
            else:
                ratio = area_ref / area if area_ref < area else area / area_ref
            area_ratio.append(ratio)
    logger.debug('End search')

    # maximum of shape similarity and upstream area accordance
    i_shape = np.argmax(inter_vs_union)
    area_shape = area_lisf[i_shape]
    i_centre = int(len(rangexy)**2 / 2) # middle point
    area_centre = area_lisf[i_centre]           
    # use middle point if errors are small
    abs_error = abs(area_shape - area_centre)
    pct_error = 100 * abs(1 - area_centre / area_shape)
    if (abs_error <= ABS_ERROR) and (pct_error <= PCT_ERROR):
        i_shape = i_centre
        area_shape = area_centre

    #i_ratio = np.argmax(area_ratio)          

    # coordinates in the fine resolution
    i = i_shape // len(rangexy)
    j = i_shape % len(rangexy)
    lat = lat_fine + rangexy[i]
    lon = lon_fine + rangexy[j]

    # coordinates and upstream area on coarse resolution
    area = upstream_coarse.sel(x=lon, y=lat, method='nearest')
    area_coarse = area.item() * 1e-6
    lon_coarse = area.x.item()
    lat_coarse = area.y.item()

    # derive catchment polygon from the selected coordinates
    basin_coarse = catchment_polygon(fdir_coarse.basins(xy=(lon_coarse, lat_coarse)).astype(np.int32),
                                     transform=ldd_coarse.rio.transform(), 
                                     crs=ldd_coarse.rio.crs,
                                     name='ID')
    basin_coarse['ID'] = ID
    basin_coarse.set_index('ID', inplace=True)
    basin_coarse[cols_fine] = lat_fine, lon_fine, area_fine
    basin_coarse[cols_coarse] = lat_coarse, lon_coarse, area_coarse

    # export shapefile
    output_shp = SHAPE_FOLDER_COARSE / f'{ID}.shp'
    basin_coarse.to_file(output_shp)
    logger.info(f'Catchment {ID} exported as shapefile: {output_shp}')

    # update new columns in 'stations'
    stations.loc[ID, cols_coarse] = lat_coarse, lon_coarse, area_coarse

# export results
stations.sort_index(axis=1, inplace=True)
output_csv = f'{Path(STATION_FILE).stem}_{suffix_coarse}.csv'
stations.to_csv(output_csv)
logger.info(f'Results have been exported to: {output_csv}')
# Out:
# 2024-08-13 13:21:41,452 | INFO | Map of upstream area corretly read: upArea_repaired.nc
# 2024-08-13 13:21:41,468 | INFO | Map of local drainage directions correctly read: ldd_3min.tif
# 2024-08-13 13:21:42,046 | INFO | Coarse resolution is 3 arcminutes
# 2024-08-13 13:21:42,062 | INFO | Table of stations correctly read: stations_MERIT.csv
# stations:   0%|          | 0/45 [00:00<?, ?it/s]
# 2024-08-13 13:21:42,142 | INFO | Catchment polygon correctly read: shapefiles\3sec\429.shp
# 2024-08-13 13:21:47,866 | INFO | Catchment 429 exported as shapefile: shapefiles\3min\429.shp
# 2024-08-13 13:21:47,886 | INFO | Catchment polygon correctly read: shapefiles\3sec\436.shp
# 2024-08-13 13:21:51,236 | INFO | Catchment 436 exported as shapefile: shapefiles\3min\436.shp
# 2024-08-13 13:21:51,254 | INFO | Catchment polygon correctly read: shapefiles\3sec\439.shp
# 2024-08-13 13:21:54,888 | INFO | Catchment 439 exported as shapefile: shapefiles\3min\439.shp
# 2024-08-13 13:21:54,898 | INFO | Catchment polygon correctly read: shapefiles\3sec\442.shp
# 2024-08-13 13:21:57,274 | INFO | Catchment 442 exported as shapefile: shapefiles\3min\442.shp
# 2024-08-13 13:21:57,286 | INFO | Catchment polygon correctly read: shapefiles\3sec\444.shp
# 2024-08-13 13:22:00,152 | INFO | Catchment 444 exported as shapefile: shapefiles\3min\444.shp
# 2024-08-13 13:22:00,164 | INFO | Catchment polygon correctly read: shapefiles\3sec\445.shp
# 2024-08-13 13:22:03,791 | INFO | Catchment 445 exported as shapefile: shapefiles\3min\445.shp
# 2024-08-13 13:22:03,803 | INFO | Catchment polygon correctly read: shapefiles\3sec\449.shp
# 2024-08-13 13:22:06,502 | INFO | Catchment 449 exported as shapefile: shapefiles\3min\449.shp
# 2024-08-13 13:22:06,522 | INFO | Catchment polygon correctly read: shapefiles\3sec\450.shp
# 2024-08-13 13:22:10,630 | INFO | Catchment 450 exported as shapefile: shapefiles\3min\450.shp
# 2024-08-13 13:22:10,650 | INFO | Catchment polygon correctly read: shapefiles\3sec\454.shp
# 2024-08-13 13:22:14,820 | INFO | Catchment 454 exported as shapefile: shapefiles\3min\454.shp
# 2024-08-13 13:22:14,832 | INFO | Catchment polygon correctly read: shapefiles\3sec\456.shp
# 2024-08-13 13:22:17,466 | INFO | Catchment 456 exported as shapefile: shapefiles\3min\456.shp
# 2024-08-13 13:22:17,476 | INFO | Catchment polygon correctly read: shapefiles\3sec\460.shp
# 2024-08-13 13:22:20,062 | INFO | Catchment 460 exported as shapefile: shapefiles\3min\460.shp
# 2024-08-13 13:22:20,078 | INFO | Catchment polygon correctly read: shapefiles\3sec\461.shp
# 2024-08-13 13:22:24,593 | INFO | Catchment 461 exported as shapefile: shapefiles\3min\461.shp
# 2024-08-13 13:22:24,609 | INFO | Catchment polygon correctly read: shapefiles\3sec\464.shp
# 2024-08-13 13:22:29,102 | INFO | Catchment 464 exported as shapefile: shapefiles\3min\464.shp
# 2024-08-13 13:22:29,124 | INFO | Catchment polygon correctly read: shapefiles\3sec\465.shp
# 2024-08-13 13:22:33,337 | INFO | Catchment 465 exported as shapefile: shapefiles\3min\465.shp
# 2024-08-13 13:22:33,349 | INFO | Catchment polygon correctly read: shapefiles\3sec\469.shp
# 2024-08-13 13:22:35,943 | INFO | Catchment 469 exported as shapefile: shapefiles\3min\469.shp
# 2024-08-13 13:22:35,968 | INFO | Catchment polygon correctly read: shapefiles\3sec\471.shp
# 2024-08-13 13:22:41,096 | INFO | Catchment 471 exported as shapefile: shapefiles\3min\471.shp
# 2024-08-13 13:22:41,108 | INFO | Catchment polygon correctly read: shapefiles\3sec\475.shp
# 2024-08-13 13:22:43,540 | INFO | Catchment 475 exported as shapefile: shapefiles\3min\475.shp
# 2024-08-13 13:22:43,562 | INFO | Catchment polygon correctly read: shapefiles\3sec\484.shp
# 2024-08-13 13:22:47,207 | INFO | Catchment 484 exported as shapefile: shapefiles\3min\484.shp
# 2024-08-13 13:22:47,225 | INFO | Catchment polygon correctly read: shapefiles\3sec\488.shp
# 2024-08-13 13:22:49,697 | INFO | Catchment 488 exported as shapefile: shapefiles\3min\488.shp
# 2024-08-13 13:22:49,727 | INFO | Catchment polygon correctly read: shapefiles\3sec\489.shp
# 2024-08-13 13:22:55,954 | INFO | Catchment 489 exported as shapefile: shapefiles\3min\489.shp
# 2024-08-13 13:22:55,976 | INFO | Catchment polygon correctly read: shapefiles\3sec\491.shp
# 2024-08-13 13:23:02,116 | INFO | Catchment 491 exported as shapefile: shapefiles\3min\491.shp
# 2024-08-13 13:23:02,135 | INFO | Catchment polygon correctly read: shapefiles\3sec\517.shp
# 2024-08-13 13:23:06,068 | INFO | Catchment 517 exported as shapefile: shapefiles\3min\517.shp
# 2024-08-13 13:23:06,076 | INFO | Catchment polygon correctly read: shapefiles\3sec\529.shp
# 2024-08-13 13:23:08,496 | INFO | Catchment 529 exported as shapefile: shapefiles\3min\529.shp
# 2024-08-13 13:23:08,508 | INFO | Catchment polygon correctly read: shapefiles\3sec\550.shp
# 2024-08-13 13:23:12,815 | INFO | Catchment 550 exported as shapefile: shapefiles\3min\550.shp
# 2024-08-13 13:23:12,833 | INFO | Catchment polygon correctly read: shapefiles\3sec\551.shp
# 2024-08-13 13:23:15,956 | INFO | Catchment 551 exported as shapefile: shapefiles\3min\551.shp
# 2024-08-13 13:23:15,976 | INFO | Catchment polygon correctly read: shapefiles\3sec\553.shp
# 2024-08-13 13:23:19,049 | INFO | Catchment 553 exported as shapefile: shapefiles\3min\553.shp
# 2024-08-13 13:23:19,069 | INFO | Catchment polygon correctly read: shapefiles\3sec\559.shp
# 2024-08-13 13:23:21,645 | INFO | Catchment 559 exported as shapefile: shapefiles\3min\559.shp
# 2024-08-13 13:23:21,668 | INFO | Catchment polygon correctly read: shapefiles\3sec\560.shp
# 2024-08-13 13:23:28,010 | INFO | Catchment 560 exported as shapefile: shapefiles\3min\560.shp
# 2024-08-13 13:23:28,026 | INFO | Catchment polygon correctly read: shapefiles\3sec\562.shp
# 2024-08-13 13:23:32,361 | INFO | Catchment 562 exported as shapefile: shapefiles\3min\562.shp
# 2024-08-13 13:23:32,375 | INFO | Catchment polygon correctly read: shapefiles\3sec\564.shp
# 2024-08-13 13:23:34,648 | INFO | Catchment 564 exported as shapefile: shapefiles\3min\564.shp
# 2024-08-13 13:23:34,676 | INFO | Catchment polygon correctly read: shapefiles\3sec\566.shp
# 2024-08-13 13:23:41,727 | INFO | Catchment 566 exported as shapefile: shapefiles\3min\566.shp
# 2024-08-13 13:23:41,739 | INFO | Catchment polygon correctly read: shapefiles\3sec\578.shp
# 2024-08-13 13:23:44,467 | INFO | Catchment 578 exported as shapefile: shapefiles\3min\578.shp
# 2024-08-13 13:23:44,489 | INFO | Catchment polygon correctly read: shapefiles\3sec\579.shp
# 2024-08-13 13:23:51,747 | INFO | Catchment 579 exported as shapefile: shapefiles\3min\579.shp
# 2024-08-13 13:23:51,766 | INFO | Catchment polygon correctly read: shapefiles\3sec\585.shp
# 2024-08-13 13:23:54,286 | INFO | Catchment 585 exported as shapefile: shapefiles\3min\585.shp
# 2024-08-13 13:23:54,327 | INFO | Catchment polygon correctly read: shapefiles\3sec\591.shp
# 2024-08-13 13:24:03,770 | INFO | Catchment 591 exported as shapefile: shapefiles\3min\591.shp
# 2024-08-13 13:24:03,788 | INFO | Catchment polygon correctly read: shapefiles\3sec\599.shp
# 2024-08-13 13:24:07,361 | INFO | Catchment 599 exported as shapefile: shapefiles\3min\599.shp
# 2024-08-13 13:24:07,393 | INFO | Catchment polygon correctly read: shapefiles\3sec\608.shp
# 2024-08-13 13:24:16,861 | INFO | Catchment 608 exported as shapefile: shapefiles\3min\608.shp
# 2024-08-13 13:24:16,893 | INFO | Catchment polygon correctly read: shapefiles\3sec\612.shp
# 2024-08-13 13:24:25,350 | INFO | Catchment 612 exported as shapefile: shapefiles\3min\612.shp
# 2024-08-13 13:24:25,390 | INFO | Catchment polygon correctly read: shapefiles\3sec\615.shp
# 2024-08-13 13:24:35,588 | INFO | Catchment 615 exported as shapefile: shapefiles\3min\615.shp
# 2024-08-13 13:24:35,600 | INFO | Catchment polygon correctly read: shapefiles\3sec\617.shp
# 2024-08-13 13:24:38,498 | INFO | Catchment 617 exported as shapefile: shapefiles\3min\617.shp
# 2024-08-13 13:24:38,524 | INFO | Catchment polygon correctly read: shapefiles\3sec\626.shp
# 2024-08-13 13:24:47,501 | INFO | Catchment 626 exported as shapefile: shapefiles\3min\626.shp
# 2024-08-13 13:24:47,531 | INFO | Catchment polygon correctly read: shapefiles\3sec\627.shp
# 2024-08-13 13:24:56,920 | INFO | Catchment 627 exported as shapefile: shapefiles\3min\627.shp
# 2024-08-13 13:24:56,950 | INFO | Catchment polygon correctly read: shapefiles\3sec\632.shp
# 2024-08-13 13:25:05,710 | INFO | Catchment 632 exported as shapefile: shapefiles\3min\632.shp
# 2024-08-13 13:25:05,740 | INFO | Catchment polygon correctly read: shapefiles\3sec\633.shp
# 2024-08-13 13:25:13,709 | INFO | Catchment 633 exported as shapefile: shapefiles\3min\633.shp
# 2024-08-13 13:25:13,750 | INFO | Catchment polygon correctly read: shapefiles\3sec\639.shp
# 2024-08-13 13:25:21,959 | INFO | Catchment 639 exported as shapefile: shapefiles\3min\639.shp
# 2024-08-13 13:25:21,971 | INFO | Results have been exported to: stations_MERIT_3min.csv
